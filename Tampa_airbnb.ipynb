# %%
import requests
import pandas as pd

# %%
rinv_tpa = requests.get("https://api.mashvisor.com/v1.1/client/airbnb-property/active-listings?state=FL&city=Tampa", headers={'x-api-key':'7b9581e3-5b45-4fbc-8f59-d3379db49449'})
rinv_tpa.json()
# Out:
# {'status': 'success',
#  'content': {'num_of_properties': 768,
#   'items': 4,
#   'total_pages': 192,
#   'page': 1,
#   'properties': [{'id': 23804871,
#     'property_id': '10193097',
#     'source': 'Airbnb',
#     'status': 'ACTIVE',
#     'night_priceـnative': 155,
#     'night_price': 160,
#     'weekly_price': 0,
#     'monthly_price': 0,
#     'cleaning_fee_native': 150,
#     'num_of_baths': 2,
#     'num_of_rooms': 3,
#     'occupancy': 35,
#     'nights_booked': 106,
#     'rental_income': 1696,
#     'airbnb_neighborhood_id': 125585,
#     'name': 'Adventurer and Nature Lovers Paradise!',
#     'address': 'Tampa, FL, United States',
#     'airbnb_neighborhood': None,
#     'airbnb_city': 'Tampa',
#     'state': 'FL',
#     'capacity_of_people': 6,
#     'zip': '33610',
#     'property_type': 'House',
#     'room_type': 'Entire home/apt',
#     'room_type_category': 'entire_home',
#     'amenities': None,
#     'reviews_count': 28,
#     'start_rating': 5,
# ...

# %%
rinv_tpafl = requests.get("https://api.mashvisor.com/v1.1/client/airbnb-property/23804871/historical?state=FL", headers={'x-api-key':'7b9581e3-5b45-4fbc-8f59-d3379db49449'})
rinv_tpafl.json()
# Out:
# {'status': 'success',
#  'content': {'name': 'Adventurer and Nature Lovers Paradise!',
#   'airbnb_id': '10193097',
#   'months': [{'airbnb_id': '10193097',
#     'name': 'Adventurer and Nature Lovers Paradise!',
#     'year': 2020,
#     'month': 5,
#     'nightly_price': 175,
#     'revenue': 700,
#     'occupancy': 4,
#     'unbooked_nights': 27,
#     'occupancy_rate': 13},
#    {'airbnb_id': '10193097',
#     'name': 'Adventurer and Nature Lovers Paradise!',
#     'year': 2020,
#     'month': 6,
#     'nightly_price': 149,
#     'revenue': 298,
#     'occupancy': 2,
#     'unbooked_nights': 28,
#     'occupancy_rate': 7},
#    {'airbnb_id': '10193097',
#     'name': 'Adventurer and Nature Lovers Paradise!',
#     'year': 2020,
#     'month': 7,
#     'nightly_price': 156,
#     'revenue': 4354,
#     'occupancy': 28,
#     'unbooked_nights': 3,
#     'occupancy_rate': 90},
#    {'airbnb_id': '10193097',
#     'name': 'Adventurer and Nature Lovers Paradise!',
#     'year': 2020,
# ...

# %%
rinv_tpafla = requests.get("https://api.mashvisor.com/v1.1/client/airbnb-property/23806582/historical?state=FL", headers={'x-api-key':'7b9581e3-5b45-4fbc-8f59-d3379db49449'})
rinv_tpafla.json()
# Out:
# {'status': 'success',
#  'content': {'name': 'Historic Seminole Heights > Best Location in Tampa',
#   'airbnb_id': '10344329',
#   'months': [{'airbnb_id': '10344329',
#     'name': 'Historic Seminole Heights > Best Location in Tampa',
#     'year': 2020,
#     'month': 5,
#     'nightly_price': 79,
#     'revenue': 158,
#     'occupancy': 2,
#     'unbooked_nights': 29,
#     'occupancy_rate': 6},
#    {'airbnb_id': '10344329',
#     'name': 'Historic Seminole Heights > Best Location in Tampa',
#     'year': 2020,
#     'month': 6,
#     'nightly_price': 79,
#     'revenue': 0,
#     'occupancy': 0,
#     'unbooked_nights': 30,
#     'occupancy_rate': 0},
#    {'airbnb_id': '10344329',
#     'name': 'Historic Seminole Heights > Best Location in Tampa',
#     'year': 2020,
#     'month': 7,
#     'nightly_price': 79,
#     'revenue': 0,
#     'occupancy': 0,
#     'unbooked_nights': 31,
#     'occupancy_rate': 0},
#    {'airbnb_id': '10344329',
# ...

# %%
rinv_tpaflor = requests.get("https://api.mashvisor.com/v1.1/client/airbnb-property/23806787/historical?state=FL", headers={'x-api-key':'7b9581e3-5b45-4fbc-8f59-d3379db49449'})
rinv_tpaflor.json()
# Out:
# {'status': 'success',
#  'content': {'name': 'Modern condo with great location. View of the Bay',
#   'airbnb_id': '10586075',
#   'months': [{'airbnb_id': '10586075',
#     'name': 'Modern condo with great location. View of the Bay',
#     'year': 2020,
#     'month': 5,
#     'nightly_price': 89,
#     'revenue': 0,
#     'occupancy': 0,
#     'unbooked_nights': 31,
#     'occupancy_rate': 0},
#    {'airbnb_id': '10586075',
#     'name': 'Modern condo with great location. View of the Bay',
#     'year': 2020,
#     'month': 6,
#     'nightly_price': 89,
#     'revenue': 0,
#     'occupancy': 0,
#     'unbooked_nights': 30,
#     'occupancy_rate': 0},
#    {'airbnb_id': '10586075',
#     'name': 'Modern condo with great location. View of the Bay',
#     'year': 2020,
#     'month': 7,
#     'nightly_price': 89,
#     'revenue': 0,
#     'occupancy': 0,
#     'unbooked_nights': 31,
#     'occupancy_rate': 0},
#    {'airbnb_id': '10586075',
# ...

# %%
rinv_tpaflorida = requests.get("https://api.mashvisor.com/v1.1/client/airbnb-property/23805019/historical?state=FL", headers={'x-api-key':'7b9581e3-5b45-4fbc-8f59-d3379db49449'})
rinv_tpaflorida.json()
# Out:
# {'status': 'success',
#  'content': {'name': 'Large Beautiful Home Feet From Bayshore Blvd',
#   'airbnb_id': '10658304',
#   'months': [{'airbnb_id': '10658304',
#     'name': 'Large Beautiful Home Feet From Bayshore Blvd',
#     'year': 2020,
#     'month': 5,
#     'nightly_price': 136,
#     'revenue': 2585,
#     'occupancy': 19,
#     'unbooked_nights': 12,
#     'occupancy_rate': 61},
#    {'airbnb_id': '10658304',
#     'name': 'Large Beautiful Home Feet From Bayshore Blvd',
#     'year': 2020,
#     'month': 6,
#     'nightly_price': 140,
#     'revenue': 2521,
#     'occupancy': 18,
#     'unbooked_nights': 12,
#     'occupancy_rate': 60},
#    {'airbnb_id': '10658304',
#     'name': 'Large Beautiful Home Feet From Bayshore Blvd',
#     'year': 2020,
#     'month': 7,
#     'nightly_price': 332,
#     'revenue': 10283,
#     'occupancy': 31,
#     'unbooked_nights': 0,
#     'occupancy_rate': 100},
#    {'airbnb_id': '10658304',
# ...

# %%
23806787

# %%
23805019
