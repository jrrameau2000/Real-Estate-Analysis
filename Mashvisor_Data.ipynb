# %%
import pandas as pd
from pathlib import Path
import plotly.express as px

# %%
Miami_Data = pd.read_excel(Path("c:/users/Tavar/Desktop/Miami Mashvisor.xlsx"))

# %%
Miami_Data
# Out:
#       Sale Type                  Home Type           Address   City State  \
# 0   MLS Listing  Single Family Residential   1745 NW 56th St  Miami    FL
# 1   MLS Listing  Single Family Residential   2010 NW 86th St  Miami    FL
# 2   MLS Listing               Multi Family    5266 NW 24 AVE  Miami    FL
# 3   MLS Listing               Multi Family    5266 NW 24 AVE  Miami    FL
# 4   MLS Listing               Multi Family    5266 NW 24 AVE  Miami    FL
# ..          ...                        ...               ...    ...   ...
# 67  MLS Listing  Single Family Residential  1861 NW 88th Ter  Miami    FL
# 68  MLS Listing  Single Family Residential   1051 NW 45th St  Miami    FL
# 69  MLS Listing  Single Family Residential  1858 NW 47th Ter  Miami    FL
# 70  MLS Listing  Single Family Residential  1340 NW 51st Ter  Miami    FL
# 71  MLS Listing  Single Family Residential   1231 NW 87th St  Miami    FL
#
#     Zip Code  Listing Price  Baths  Beds  SQFT  ...  Year Built  \
# ...

# %%
Miami_Data.groupby("Zip Code").mean()
# Out:
#           Listing Price     Baths      Beds         SQFT     Lot Size  \
# Zip Code
# 33015     314000.000000  2.000000  2.000000  1446.000000   436.000000
# 33127     373557.142857  1.285714  2.285714  1317.857143  5752.571429
# 33142     302842.857143  1.190476  1.857143  1061.809524  4873.571429
# 33147     275055.148148  1.592593  2.703704  1073.518519  6334.962963
# 33150     254333.166667  1.666667  3.000000   902.000000  4356.000000
# 33167     327842.857143  1.428571  2.857143   900.142857  5600.571429
# 33168     264500.000000  1.500000  2.500000   760.000000  4138.000000
# 33169     339000.000000  1.000000  3.000000  1803.000000     0.000000
#
#            Year Built  Parking Spots  Days on Market  Recent Reduction Date  \
# Zip Code
# 33015     1986.000000       0.000000       24.000000                    0.0
# 33127     1937.285714       1.714286       91.571429                    0.0
# 33142     1968.095238       1.571429      256.952381                    0.0
# ...

# %%
Orlando_Data = pd.read_excel(Path("c:/users/Tavar/Desktop/Orlando Data.xlsx"))

# %%
Orlando_Data
# Out:
#       Sale Type                  Home Type                         Address  \
# 0   MLS Listing                 Condo/Coop      5319 INDIAN CREEK DRIVE #D
# 1   MLS Listing                 Condo/Coop   5304 JASMINE CREEK LANE #1306
# 2   MLS Listing  Single Family Residential          6007 PINE VALLEY DRIVE
# 3   MLS Listing                 Condo/Coop     5401 PINE CREEK DRIVE #1806
# 4   MLS Listing  Single Family Residential            6351 PINEY GLEN LANE
# 5   MLS Listing                 Condo/Coop     5491 PINE CREEK DRIVE #1906
# 6   MLS Listing  Single Family Residential  6312 Piney Glen Ln, Orlando Fl
# 7   MLS Listing                 Condo/Coop      5318 PEBBLE BEACH DRIVE #D
# 8   MLS Listing                 Condo/Coop           5858 PEREGRINE AVENUE
# 9   MLS Listing                 Condo/Coop     5414 PINE CREEK DRIVE #1612
# 10  MLS Listing  Single Family Residential               6315 MARINA DRIVE
# ...

# %%
Orlando_Data.groupby("Zip Code").mean()
# Out:
#           Listing Price     Baths      Beds         SQFT      Lot Size  \
# Zip Code
# 32811          142787.5  2.125000  2.250000  1228.375000   4029.375000
# 32819          468200.0  2.769231  3.076923  2140.769231  12464.769231
# 32836          526475.0  3.000000  3.500000  2846.000000   8494.000000
#
#            Year Built  Parking Spots  Days on Market  Recent Reduction Date  \
# Zip Code
# 32811     1973.000000       1.125000      157.625000                    0.0
# 32819     1977.846154       1.307692       51.538462                    0.0
# 32836     2015.500000       3.000000       19.500000                    0.0
#
#           Original Listing Price  Airbnb Cash on Cash  Airbnb Cap Rate  \
# Zip Code
# 32811                        0.0              1.56962         0.049242
# 32819                        0.0              1.56962         2.212635
# 32836                        0.0              1.56962         2.378785
#
# ...

# %%
Tampa_Data = pd.read_excel(Path("c:/users/Tavar/Desktop/Tampa Data.xlsx"))

# %%
Tampa_Data
# Out:
#       Sale Type                  Home Type                           Address  \
# 0   MLS Listing  Single Family Residential          7708 W POCAHONTAS AVENUE
# 1   MLS Listing                 Condo/Coop   4311 BAYSIDE VILLAGE DRIVE #201
# 2   MLS Listing                 Condo/Coop         6336 NEWTOWN CIRCLE #36C1
# 3   MLS Listing  Single Family Residential      12408 BRISTOL COMMONS CIRCLE
# 4   MLS Listing  Single Family Residential              4631 DRIESLER CIRCLE
# 5   MLS Listing                  Townhouse              9595 CAVENDISH DRIVE
# 6   MLS Listing                 Condo/Coop            9213 TUDOR DRIVE #B205
# 7   MLS Listing                 Condo/Coop            9008 TUDOR DRIVE #K206
# 8   MLS Listing                 Condo/Coop     10476 SAINT TROPEZ PLACE #102
# 9   MLS Listing                 Condo/Coop  9266 LAKE CHASE ISLAND WAY #9266
# 10  MLS Listing                 Condo/Coop  7909 PALMERA POINTE CIRCLE #7909
# ...

# %%
Tampa_Data.groupby("Zip Code").mean()
# Out:
#           Listing Price     Baths      Beds         SQFT      Lot Size  \
# Zip Code
# 33607     245000.000000  1.000000  1.000000   516.000000      0.000000
# 33615     327096.466667  2.266667  2.800000  1614.633333   8436.133333
# 33617     194000.000000  2.000000  2.000000  1153.000000      0.000000
# 33625     324000.000000  2.000000  3.000000  1700.000000  11326.000000
# 33626     425693.266667  2.933333  3.266667  2177.400000   3775.333333
# 33634     260725.000000  2.250000  3.000000  1384.000000   5336.000000
# 33635     242450.000000  2.500000  3.000000  1080.000000   2396.000000
#
#            Year Built  Parking Spots  Days on Market  Recent Reduction Date  \
# Zip Code
# 33607     1982.000000       2.000000       14.000000                    0.0
# 33615     1920.533333       0.866667       40.500000                    0.0
# 33617     2000.000000       0.000000        2.000000                    0.0
# ...

# %%
Long_Lat = pd.read_excel(Path("c:/users/Tavar/Desktop/longitude & Latitude real estate.xlsx"))

# %%
Long_Lat.head()
# Out:
#            Address   Latitude  Longitude                Location   City State  \
# 0  1745 NW 56th St  25.826807 -80.225618  25.8268071,-80.2256177  Miami    FL
# 1  2010 NW 86th St  25.852324 -80.230933  25.8523237,-80.2309332  Miami    FL
# 2   5266 NW 24 AVE  25.823542 -80.236955    25.823542,-80.236955  Miami    FL
# 3   5266 NW 24 AVE  25.823542 -80.236955    25.823542,-80.236955  Miami    FL
# 4   5266 NW 24 AVE  25.823542 -80.236955    25.823542,-80.236955  Miami    FL
#
#    Zip Code  Listing Price
# 0   33142.0       285000.0
# 1   33147.0       329900.0
# 2   33142.0       455000.0
# 3   33142.0       455000.0
# 4   33142.0       455000.0

# %%
api_key = "pk.eyJ1IjoidGF2YXJpc2pvbmVzIiwiYSI6ImNrbXpseGg0bjBmMXoydW1vdWV5bjdubzcifQ.Kf7Y79pWddzpAyrDCCpeyw"

# %%
px.set_mapbox_access_token(api_key)

# %%
map1 = px.scatter_mapbox(
Long_Lat,
lat= "Latitude",
lon="Longitude",
color = "Listing Price")
map1
