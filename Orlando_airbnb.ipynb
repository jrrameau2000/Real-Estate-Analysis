# %%
import requests
import pandas as pd

# %%
inv_orlfl = requests.get("https://api.mashvisor.com/v1.1/client/airbnb-property/23782442/historical?state=FL", headers={'x-api-key':'7b9581e3-5b45-4fbc-8f59-d3379db49449'})
rinv_orlfl = inv_orlfl.json()
rinv_orlfl
# Out:
# {'status': 'success',
#  'content': {'name': 'Cozzy modern spacious 2B/2Bth',
#   'airbnb_id': '10117384',
#   'months': [{'airbnb_id': '10117384',
#     'name': 'Cozzy modern spacious 2B/2Bth',
#     'year': 2020,
#     'month': 5,
#     'nightly_price': 99,
#     'revenue': 891,
#     'occupancy': 9,
#     'unbooked_nights': 22,
#     'occupancy_rate': 29},
#    {'airbnb_id': '10117384',
#     'name': 'Cozzy modern spacious 2B/2Bth',
#     'year': 2020,
#     'month': 6,
#     'nightly_price': 99,
#     'revenue': 0,
#     'occupancy': 0,
#     'unbooked_nights': 30,
#     'occupancy_rate': 0},
#    {'airbnb_id': '10117384',
#     'name': 'Cozzy modern spacious 2B/2Bth',
#     'year': 2020,
#     'month': 7,
#     'nightly_price': 99,
#     'revenue': 1188,
#     'occupancy': 12,
#     'unbooked_nights': 19,
#     'occupancy_rate': 39},
#    {'airbnb_id': '10117384',
#     'name': 'Cozzy modern spacious 2B/2Bth',
#     'year': 2020,
#     'month': 8,
#     'nightly_price': 99,
# ...

# %%
rinv_orlfla = pd.DataFrame.from_dict(rinv_orlfl['content']['months']) 
rinv_orlfla_del = rinv_orlfla.drop(columns=['airbnb_id', 'name',])
rinv_orlfla_del
# Out:
#     year  month  nightly_price  revenue  occupancy  unbooked_nights  \
# 0   2020      5             99      891          9               22
# 1   2020      6             99        0          0               30
# 2   2020      7             99     1188         12               19
# 3   2020      8             99      891          9               22
# 4   2020      9             99        0          0               30
# 5   2020     10             99        0          0               31
# 6   2020     11            105        0          0               30
# 7   2020     12            120        0          0               31
# 8   2021      1             99     1782         18               13
# 9   2021      2             99      495          5               23
# 10  2021      3             99     3069         31                0
# 11  2021      4             99      693          7               23
#
#     occupancy_rate
# 0               29
# 1                0
# 2               39
# ...

# %%
orl_fla = requests.get("https://api.mashvisor.com/v1.1/client/airbnb-property/23782274/historical?state=FL", headers={'x-api-key':'7b9581e3-5b45-4fbc-8f59-d3379db49449'})
orlando_fl = orl_fla.json()
orlando_fl
# Out:
# {'status': 'success',
#  'content': {'name': 'Lakefront Tropical Oasis w/ Pool, Hot Tub, Boating',
#   'airbnb_id': '10342217',
#   'months': [{'airbnb_id': '10342217',
#     'name': 'Lakefront Tropical Oasis w/ Pool, Hot Tub, Boating',
#     'year': 2020,
#     'month': 5,
#     'nightly_price': 232,
#     'revenue': 6493,
#     'occupancy': 28,
#     'unbooked_nights': 3,
#     'occupancy_rate': 90},
#    {'airbnb_id': '10342217',
#     'name': 'Lakefront Tropical Oasis w/ Pool, Hot Tub, Boating',
#     'year': 2020,
#     'month': 6,
#     'nightly_price': 236,
#     'revenue': 5659,
#     'occupancy': 24,
#     'unbooked_nights': 6,
#     'occupancy_rate': 80},
#    {'airbnb_id': '10342217',
#     'name': 'Lakefront Tropical Oasis w/ Pool, Hot Tub, Boating',
#     'year': 2020,
#     'month': 7,
#     'nightly_price': 253,
#     'revenue': 6327,
#     'occupancy': 25,
#     'unbooked_nights': 6,
#     'occupancy_rate': 81},
#    {'airbnb_id': '10342217',
# ...

# %%
orlando_fla = pd.DataFrame.from_dict(orlando_fl['content']['months'])
orlando_fla_drop = orlando_fla.drop(columns=['airbnb_id', 'name',])
orlando_fla_drop
# Out:
#     year  month  nightly_price  revenue  occupancy  unbooked_nights  \
# 0   2020      5            232     6493         28                3
# 1   2020      6            236     5659         24                6
# 2   2020      7            253     6327         25                6
# 3   2020      8            221     5956         27                4
# 4   2020      9            195     4279         22                8
# 5   2020     10            249     7231         29                2
# 6   2020     11            234     5157         22                8
# 7   2020     12            317     8247         26                5
# 8   2021      3            304     9423         31                0
# 9   2021      4            332     7962         24                6
# 10  2021      1            227     4082         18               13
# 11  2021      2            245     5882         24                4
#
#     occupancy_rate
# 0               90
# 1               80
# 2               81
# ...

# %%
rinv_orlflor = requests.get("https://api.mashvisor.com/v1.1/client/airbnb-property/23783498/historical?state=FL", headers={'x-api-key':'7b9581e3-5b45-4fbc-8f59-d3379db49449'})
orl_flor = rinv_orlflor.json()
orl_flor
# Out:
# {'status': 'success',
#  'content': {'name': 'Location Location Location in Historic Winter Park',
#   'airbnb_id': '10400432',
#   'months': [{'airbnb_id': '10400432',
#     'name': 'Location Location Location in Historic Winter Park',
#     'year': 2020,
#     'month': 5,
#     'nightly_price': 350,
#     'revenue': 1050,
#     'occupancy': 3,
#     'unbooked_nights': 28,
#     'occupancy_rate': 10},
#    {'airbnb_id': '10400432',
#     'name': 'Location Location Location in Historic Winter Park',
#     'year': 2020,
#     'month': 6,
#     'nightly_price': 230,
#     'revenue': 0,
#     'occupancy': 0,
#     'unbooked_nights': 30,
#     'occupancy_rate': 0},
#    {'airbnb_id': '10400432',
#     'name': 'Location Location Location in Historic Winter Park',
#     'year': 2020,
#     'month': 7,
#     'nightly_price': 207,
#     'revenue': 0,
#     'occupancy': 0,
#     'unbooked_nights': 31,
#     'occupancy_rate': 0},
#    {'airbnb_id': '10400432',
# ...

# %%
orlando_flor = pd.DataFrame.from_dict(orl_flor['content']['months'])
orlando_flor_drop = orlando_flor.drop(columns=['airbnb_id', 'name',])
orlando_flor_drop
# Out:
#     year  month  nightly_price  revenue  occupancy  unbooked_nights  \
# 0   2020      5            350     1050          3               28
# 1   2020      6            230        0          0               30
# 2   2020      7            207        0          0               31
# 3   2020      8            230        0          0               31
# 4   2020      9            230     1380          6               24
# 5   2020     10            230        0          0               31
# 6   2020     11            218     6550         30                0
# 7   2020     12            230     1150          5               26
# 8   2021      1            230     6900         30                1
# 9   2021      2            230     6440         28                0
# 10  2021      3            230        0          0               31
# 11  2021      4            190        0          0               30
#
#     occupancy_rate
# 0               10
# 1                0
# 2                0
# ...

# %%
orl_airbnb = pd.
orl_airbnb
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-df9f0589074c> in <module>
# ----> 1 orl_airbnb = pd.concat([orlando_fl, orlando_fla_drop, orlando_fla_drop], axis="columns", join="inner")
#       2 orl_airbnb
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     368                     "only Series and DataFrame objs are valid"
#     369                 )
# --> 370                 raise TypeError(msg)
#     371
# ...
