# %%
import requests

# %%
mia_prop = requests.get('"https://api.mashvisor.com/v1.1/client/airbnb-property/21419158/historical?state=FL"', headers={'x-api-key':'7b9581e3-5b45-4fbc-8f59-d3379db49449'} )
mia_prop.json()
# Out:
# {'status': 'success',
#  'content': {'properties': [{'id': 1930263,
#     'neighborhood': 'Liberty City',
#     'neighborhood_id': 269093,
#     'address': '801 NW 75th',
#     'zip_code': 33150,
#     'zip': 33150,
#     'city': 'Miami',
#     'county': 'MIAMI-DADE COUNTY',
#     'state': 'FL',
#     'type': 'Single Family Residential',
#     'image_url': None,
#     'list_price': 250000,
#     'baths': 3,
#     'beds': 4,
#     'sqft': None,
#     'mls_id': 'A11011860',
#     'days_on_market': 43,
#     'next_open_house_date': None,
#     'next_open_house_start_time': None,
#     'next_open_house_end_time': None,
#     'last_sale_date': None,
#     'last_sale_price': None,
#     'listing_id': 'A11011860',
#     'has_pool': None,
#     'is_water_front': None,
#     'num_of_units': None,
#     'latitude': 25.8435,
#     'longitude': -80.2112,
#     'traditional_ROI': 5.76608,
#     'airbnb_ROI': 9.9876,
#     'traditional_rental': 1906.5,
#     'airbnb_rental': 3687.11,
# ...
